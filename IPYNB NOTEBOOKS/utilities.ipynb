# %% [markdown]
# requirements.txt file generator

# %%
pip freeze > requirements.txt

# %% [markdown]
# File counter

# %%
import os, os.path
from pathlib import Path
path, dirs, files = next(os.walk('/content/images_new_withbox'))
print(len(files))

# %% [markdown]
# Pbar

# %%
from tqdm import tqdm
from time import sleep
pbar = tqdm(total=2000, bar_format ='{l_bar}{bar}|  {n_fmt}/{total_fmt}  [ Elapsed Time : {elapsed} | ETA : {remaining} ]', leave=True, position=0)
for i in range(2000):
    sleep(0.1)
    pbar.update(1)

# %% [markdown]
# copy contents on drive

# %%
# !cp source_file/folder destination
or
# !cp 'source_file/folder' 'destination'

# %% [markdown]
# Delete

# %%
# !rm  <file_name>            #for file
# !rm -rf <folder_name>       #for foler
or
# !rm -rf '<folder_name>'

# %% [markdown]
# Move contents

# %%
import shutil
shutil.move("path/to/current/file", "path/to/new/destination/for/file")

# %% [markdown]
# unzip

# %%
# !pip install py7zr
import py7zr
from re import findall
from pathlib import Path
from shutil import rmtree

make_dir = Path('/content/dirnamehere')
path_to_source_folder = Path('/content/drive/MyDrive/pathtothezipfile')
if make_dir.exists(): rmtree(make_dir)
make_dir.mkdir()

if findall('.7z', str(path_to_source_folder)):
    with py7zr.SevenZipFile(path_to_source_folder, mode='r') as z:
        z.extractall(make_dir)
    path_to_source_folder = Path('/content/dirnamehere/pathtothesourcefolderinzip')
elif findall('.zip', str(path_to_source_folder)):
    # !unzip $path_to_source_folder -d /content/ASLdataset
    path_to_source_folder = Path('/content/dirnamehere/pathtothesourcefolderinzip')
else:
    path_to_source_folder = Path(path_to_source_folder)

# %%
# !pip install py7zr
import py7zr
from re import findall
from pathlib import Path
from shutil import rmtree

make_dir = Path('/content/dirnamehere')
path_to_source_folder = Path('/content/drive/MyDrive/23march.7z')
if make_dir.exists(): rmtree(make_dir)
make_dir.mkdir()

if findall('.7z', str(path_to_source_folder)):
    with py7zr.SevenZipFile(path_to_source_folder, mode='r') as z:
        z.extractall(make_dir)
    path_to_source_folder = Path('/content/dirnamehere/pathtothesourcefolderinzip')
elif findall('.zip', str(path_to_source_folder)):
    # !unzip $path_to_source_folder -d /content/ASLdataset
    path_to_source_folder = Path('/content/dirnamehere/pathtothesourcefolderinzip')
else:
    path_to_source_folder = Path(path_to_source_folder)

# %%
import os, os.path
from pathlib import Path
path, dirs, files = next(os.walk('/content/dirnamehere/failure/Age'))
print(len(files))
# Out:
# 850

# %% [markdown]
# ZIP

# %%
# !zip -r /content/destination/file.zip /content/folder/location


CREATE
import py7zr
with py7zr.SevenZipFile("Archive.7z", 'w') as archive:
    archive.writeall("target/")

APPEND
import py7zr
with py7zr.SevenZipFile("Archive.7z", 'a') as archive:
    archive.write("additional_file.txt")

# %% [markdown]
# Make dir

# %% [markdown]
# Select all files in directory which have class in thier name or any string

# %%
from pandas import DataFrame, read_csv, get_dummies, Series, concat
csv_list = []
source_directory = '/content/Output'
videos_per_class = 100
classes = [ 'Bird' ]
for category in classes:
    print(str(source_directory)+'/'+category)
    tempo_dir = random.sample(os.listdir(str(source_directory)), videos_per_class)
    cat_dir=[]
    for directory in tempo_dir:
        if 'Bird' in directory:
            cat_dir.append(Path((source_directory+'/'+directory)))
    csv_list.append(cat_dir)
print(len(csv_list[0]))
print(csv_list)

# %%
print(helo[0])

# %%
# !pip install py7zr
import py7zr
from re import findall
from pathlib import Path
from shutil import rmtree

make_dir = Path('/content/dirnamehere')
path_to_source_folder = Path('/content/drive/MyDrive/pathtothezipfile')
if make_dir.exists(): rmtree(make_dir)
make_dir.mkdir()

if findall('.7z', str(path_to_source_folder)):
    with py7zr.SevenZipFile(path_to_source_folder, mode='r') as z:
        z.extractall(make_dir)
    path_to_source_folder = Path('/content/dirnamehere/pathtothesourcefolderinzip')
elif findall('.zip', str(path_to_source_folder)):
    # !unzip $path_to_source_folder -d /content/ASLdataset
    path_to_source_folder = Path('/content/dirnamehere/pathtothesourcefolderinzip')
else:
    path_to_source_folder = Path(path_to_source_folder)

# %%
import os, os.path
from pathlib import Path
path, dirs, files = next(os.walk('/content/drive/MyDrive/rohit+vihang_videos/aug_vid/Movie'))
print(len(files))
out_prefix = '/content/drive/MyDrive/rohit+vihang_videos/augmented_csv/phone/'
new_list =[]
count =0
# for file in files:
#     filename = out_prefix + 'phone_' + file
#     my_file = Path(filename[:-4]+'.csv')
#     if not my_file.exists():
#         count +=1
#         filename = '/content/drive/MyDrive/rohit+vihang_videos/augmented/phone/' + file
#         new_list.append(filename)
# print(new_list[0])
print(count)
# Out:
# 999
# 0
