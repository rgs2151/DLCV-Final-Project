# %%
ERROR_EMAIL = '1234rohitb@gmail.com,azyo.asl@gmail.com'

# %%
res = [ERROR_EMAIL.split() for item in ]

# %%
result = [x.strip() for x in ERROR_EMAIL.split(',')]
print(result)
# Out:
# ['1234rohitb@gmail.com', 'azyo.asl@gmail.com']

# %%
list = ['LICENCE NO', 'NAME', 'DOB', 'CARE OF', 'ADDRESS', 'DATE OF ISSUE', 'DATE OF EXPIRY']

# %%
print(ERROR_EMAIL + str(list))
# Out:
# 1234rohitb@gmail.com,azyo.asl@gmail.com['LICENCE NO', 'NAME', 'DOB', 'CARE OF', 'ADDRESS', 'DATE OF ISSUE', 'DATE OF EXPIRY']
