# %%
import shutil

# %%
shutil.move('/content/drive/MyDrive/rohit+vihang_videos/augmented_csv_1','/content/drive/MyDrive/rohit+vihang_videos/augmented_csv_2')
# Out:
# '/content/drive/MyDrive/rohit+vihang_videos/augmented_csv_2/augmented_csv_1'

# %%
import csv 
from pandas import read_csv 
# field names 
fields = ['Name', 'Branch', 'Year', 'CGPA'] 
    
# data rows of csv file 
rows = [ ['Nikhil', 'COE', '2', '9.0'], 
         ['Sanchit', 'COE', '2', '9.1'], 
         ['Aditya', 'IT', '2', '9.3'], 
         ['Sagar', 'SE', '1', '9.5'], 
         ['Prateek', 'MCE', '3', '7.8'], 
         ['Sahil', 'EP', '2', '9.1']] 
    
# name of csv file 
filename = "university_records.csv"
    
# writing to csv file 
with open(filename, 'a+') as csvfile: 
    # creating a csv writer object 
    csvwriter = csv.writer(csvfile) 
    sniffer = csv.Sniffer()
    print(csv.Sniffer().has_header(csvfile.read(1)))
    print(csvfile.seek(0))
    # csvwriter.writerow(fields)
    # csvwriter.writerows(rows)
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# <ipython-input-14-f8d96e672c44> in <module>()
#      20     csvwriter = csv.writer(csvfile)
#      21     sniffer = csv.Sniffer()
# ---> 22     print(csv.Sniffer().has_header(csvfile.read(1)))
#      23     print(csvfile.seek(0))
#      24     # csvwriter.writerow(fields)
#
# /usr/lib/python3.7/csv.py in has_header(self, sample)
#     392         # subtracting from the likelihood of the first row being a header.
#     393
# --> 394         rdr = reader(StringIO(sample), self.sniff(sample))
#     395
#     396         header = next(rdr) # assume first row is header
#
# /usr/lib/python3.7/csv.py in sniff(self, sample, delimiters)
#     186
#     187         if not delimiter:
# --> 188             raise Error("Could not determine delimiter")
#     189
#     190         class dialect(Dialect):
#
# Error: Could not determine delimiter
